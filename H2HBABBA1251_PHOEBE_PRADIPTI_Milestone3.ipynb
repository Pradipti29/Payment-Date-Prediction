# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import LabelEncoder
from forex_python.converter import CurrencyRates 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

pd. set_option('display.max_columns', 1000) 
pd. set_option('display.max_rows', 1000)

from datetime import datetime
from datetime import timedelta

# %%
#reading the dataset
data=pd.read_csv('H2HBABBA1251.csv')

# %%
df=pd.DataFrame(data)

# %%
#dropping a column 
df=df.drop('area_business',axis=1)

# %%
df.shape
# Out:
# (50000, 18)

# %%
#using fillna method
df['invoice_id'].fillna(df['doc_id'], inplace=True)

# %%
#checking the null values
df.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    0
# isOpen                        0
# dtype: int64

# %%
#checking the duplicate 
df_trans = df.T
df_trans.duplicated()
# Out:
# business_code             False
# cust_number               False
# name_customer             False
# clear_date                False
# buisness_year             False
# doc_id                    False
# posting_date              False
# document_create_date      False
# document_create_date.1    False
# due_in_date               False
# invoice_currency          False
# document type             False
# posting_id                False
# total_open_amount         False
# baseline_create_date      False
# cust_payment_terms        False
# invoice_id                 True
# isOpen                    False
# dtype: bool

# %%
(df['doc_id'] == df['invoice_id']).sum()
# Out:
# 50000

# %%
#dropping a column
df = df.drop(columns=['doc_id'])

# %%
(df['document_create_date'] == df['document_create_date.1']).sum()
# Out:
# 20899

# %%
df = df.drop(columns=['document_create_date.1'])

# %%
#checking unique value
df.nunique()
# Out:
# business_code               6
# cust_number              1421
# name_customer            4207
# clear_date                400
# buisness_year               2
# posting_date              505
# document_create_date      507
# due_in_date               550
# invoice_currency            2
# document type               2
# posting_id                  1
# total_open_amount       44195
# baseline_create_date      504
# cust_payment_terms         70
# invoice_id              48886
# isOpen                      2
# dtype: int64

# %%
df.drop(columns = ['posting_id'],axis=1,inplace=True)

# %%
#checking the null value and then separate into train,test
train_df=df[df['clear_date'].notnull()]

# %%
test_df=df[df['clear_date'].isnull()]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_code         40000 non-null  object
#  1   cust_number           40000 non-null  object
#  2   name_customer         40000 non-null  object
#  3   clear_date            40000 non-null  object
#  4   buisness_year         40000 non-null  float64
#  5   posting_date          40000 non-null  object
#  6   document_create_date  40000 non-null  int64
#  7   due_in_date           40000 non-null  float64
#  8   invoice_currency      40000 non-null  object
#  9   document type         40000 non-null  object
#  10  total_open_amount     40000 non-null  float64
#  11  baseline_create_date  40000 non-null  float64
#  12  cust_payment_terms    40000 non-null  object
#  13  invoice_id            40000 non-null  float64
#  14  isOpen                40000 non-null  int64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 4.9+ MB

# %%
#changing to datetime
train_df['clear_date']=pd.to_datetime(train_df['clear_date'])
test_df['clear_date']=pd.to_datetime(test_df['clear_date'])

# %%
train_df['posting_date']=pd.to_datetime(train_df['posting_date'])
test_df['posting_date']=pd.to_datetime(test_df['posting_date'])

# %%
train_df['document_create_date']=pd.to_datetime(train_df['document_create_date'], format='%Y%m%d')
test_df['document_create_date']=pd.to_datetime(test_df['document_create_date'], format='%Y%m%d')

# %%
train_df['due_in_date']=pd.to_datetime(train_df['due_in_date'], format='%Y%m%d')
test_df['due_in_date']=pd.to_datetime(test_df['due_in_date'], format='%Y%m%d')

# %%
train_df['baseline_create_date']=pd.to_datetime(train_df['baseline_create_date'], format='%Y%m%d')
test_df['baseline_create_date']=pd.to_datetime(test_df['baseline_create_date'], format='%Y%m%d')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_code         40000 non-null  object
#  1   cust_number           40000 non-null  object
#  2   name_customer         40000 non-null  object
#  3   clear_date            40000 non-null  datetime64[ns]
#  4   buisness_year         40000 non-null  float64
#  5   posting_date          40000 non-null  datetime64[ns]
#  6   document_create_date  40000 non-null  datetime64[ns]
#  7   due_in_date           40000 non-null  datetime64[ns]
#  8   invoice_currency      40000 non-null  object
#  9   document type         40000 non-null  object
#  10  total_open_amount     40000 non-null  float64
#  11  baseline_create_date  40000 non-null  datetime64[ns]
#  12  cust_payment_terms    40000 non-null  object
#  13  invoice_id            40000 non-null  float64
#  14  isOpen                40000 non-null  int64
# dtypes: datetime64[ns](5), float64(3), int64(1), object(6)
# memory usage: 4.9+ MB

# %%
train_df['invoice_id']=train_df['invoice_id'].astype(str)
test_df['invoice_id']=test_df['invoice_id'].astype(str)

# %%
train_df['buisness_year']=train_df['buisness_year'].astype(str)
train_df['buisness_year']=train_df['buisness_year'].str[:-2]
test_df['buisness_year']=test_df['buisness_year'].astype(str)
test_df['buisness_year']=test_df['buisness_year'].str[:-2]

# %%
train_df
# Out:
#       business_code cust_number        name_customer clear_date buisness_year  \
# 0              U001  0200769623      WAL-MAR systems 2019-04-19          2019
# 1              U001  0200124634   BAKEMAR associates 2020-03-11          2020
# 2              U001  0200759878                SA us 2019-01-28          2019
# 3              U001  0200769623   WAL-MAR associates 2019-01-25          2019
# 5              U001  0200799367             MCL corp 2019-11-04          2019
# ...             ...         ...                  ...        ...           ...
# 49995          U001  0200769623  WAL-MAR corporation 2019-05-17          2019
# 49996          U001  0200777735     NASH  foundation 2020-01-21          2020
# 49997          U001  0200965912          C&S W trust 2019-12-02          2019
# 49998          U001  0200729942              SA corp 2019-10-29          2019
# 49999          U001  0200762950            HAR trust 2019-12-20          2019
#
#       posting_date document_create_date due_in_date invoice_currency  \
# 0       2019-04-03           2019-04-03  2019-04-18              USD
# 1       2020-02-26           2020-02-26  2020-03-07              USD
# 2       2019-01-05           2019-01-04  2019-01-20              USD
# 3       2019-01-15           2019-01-14  2019-01-30              USD
# 5       2019-10-18           2019-10-17  2019-11-02              USD
# ...            ...                  ...         ...              ...
# 49995   2019-05-07           2019-05-06  2019-05-22              USD
# 49996   2020-01-06           2020-01-06  2020-01-21              USD
# 49997   2019-11-14           2019-11-14  2019-11-29              USD
# 49998   2019-10-14           2019-10-14  2019-10-29              USD
# 49999   2019-12-06           2019-12-05  2019-12-21              USD
#
#       document type  total_open_amount baseline_create_date  \
# 0                RV           55602.94           2019-04-03
# 1                RV            8345.60           2020-02-26
# 2                RV           13768.73           2019-01-05
# 3                RV            7463.23           2019-01-15
# 5                RV           18501.55           2019-10-18
# ...             ...                ...                  ...
# 49995            RV            6532.60           2019-05-07
# 49996            RV           84123.80           2020-01-06
# 49997            RV           22325.58           2019-11-14
# 49998            RV           25563.51           2019-10-14
# 49999            RV          161070.91           2019-12-06
#
#       cust_payment_terms    invoice_id  isOpen
# 0                   NAH4  1929075498.0       0
# 1                   NA10  1930572616.0       0
# 2                   NAH4  1928566866.0       0
# 3                   NAH4  1928619184.0       0
# 5                   NAA8  1930024400.0       0
# ...                  ...           ...     ...
# 49995               NAH4  1929270469.0       0
# 49996               NAA8  1930362933.0       0
# 49997               NAC6  1930153056.0       0
# 49998               NAA8  1930013127.0       0
# 49999               NAA8  1930219052.0       0
#
# [40000 rows x 15 columns]

# %%
#finding the target value
train_df["delay"] = train_df["clear_date"] - train_df["due_in_date"]

# %%
#sorting the dataframe using sort function
train_df=train_df.sort_values(by = 'posting_date')

# %%
train_df.head()
# Out:
#       business_code cust_number        name_customer clear_date buisness_year  \
# 380            U001  0200755701           ASSOCI llc 2019-01-15          2019
# 8784           U001  0200769623          WAL-MAR llc 2019-01-15          2019
# 9879           U001  0200769623           WAL-MAR us 2019-01-15          2019
# 15448          U001  0200705372                  FR  2019-01-14          2019
# 14959          U001  0200769623  WAL-MAR corporation 2019-01-10          2019
#
#       posting_date document_create_date due_in_date invoice_currency  \
# 380     2018-12-30           2018-12-29  2019-01-14              USD
# 8784    2018-12-30           2018-12-29  2019-01-14              USD
# 9879    2018-12-30           2018-12-29  2019-01-14              USD
# 15448   2018-12-30           2018-12-29  2019-01-14              USD
# 14959   2018-12-30           2018-12-29  2019-01-14              USD
#
#       document type  total_open_amount baseline_create_date  \
# 380              RV           18655.77           2018-12-30
# 8784             RV           20467.17           2018-12-30
# 9879             RV            4439.84           2018-12-30
# 15448            RV           66586.13           2018-12-30
# 14959            RV            8730.88           2018-12-30
#
#       cust_payment_terms    invoice_id  isOpen   delay
# 380                 NAA8  1928536837.0       0  1 days
# 8784                NAH4  1928541056.0       0  1 days
# 9879                NAH4  1928540938.0       0  1 days
# 15448               NAA8  1928537402.0       0  0 days
# 14959               NAH4  1928538220.0       0 -4 days

# %%
train_df.nunique()
# Out:
# business_code               6
# cust_number              1339
# name_customer            3912
# clear_date                400
# buisness_year               2
# posting_date              423
# document_create_date      426
# due_in_date               492
# invoice_currency            2
# document type               2
# total_open_amount       35508
# baseline_create_date      428
# cust_payment_terms         67
# invoice_id              39136
# isOpen                      1
# delay                     192
# dtype: int64

# %%
train_df.drop(columns = ['isOpen'],axis=1,inplace=True)
test_df.drop(columns = ['isOpen'],axis=1,inplace=True)

# %%
train_df.drop(columns = ['invoice_id'],axis=1,inplace=True)
test_df.drop(columns = ['invoice_id'],axis=1,inplace=True)

# %%
train_df.shape,test_df.shape
# Out:
# ((40000, 14), (10000, 13))

# %%
duplicate_value = train_df.duplicated()

# %%
train_df[duplicate_value].shape
# Out:
# (871, 14)

# %%
train_df.drop_duplicates(keep='first',inplace=True)

# %%
train_df.shape
# Out:
# (39129, 14)

# %%
#changing the datatype
train_df['delay'] = train_df['delay'].dt.days

# %%
train_df['delay']
# Out:
# 380      1
# 8784     1
# 9879     1
# 15448    0
# 14959   -4
#         ..
# 13758   -3
# 13125    7
# 41892    3
# 37929    0
# 35156   -1
# Name: delay, Length: 39129, dtype: int64

# %%
train_df['business_code']=np.where(train_df['business_code'].isin([ 'U005', 'U007']),
                                   'Other Codes',train_df['business_code'])
test_df['business_code']=np.where(test_df['business_code'].isin([ 'U005', 'U007']),
                                   'Other Codes',test_df['business_code'])

# %% [markdown]
# # Feature Engineering

# %%
business_code_encoder = LabelEncoder()
business_code_encoder1 = LabelEncoder()
business_code_encoder.fit(train_df['business_code'])
business_code_encoder1.fit(test_df['business_code'])
train_df['business_code'] = business_code_encoder.transform(train_df['business_code'])
test_df['business_code'] = business_code_encoder1.transform(test_df['business_code'])

# %%
train_df.cust_payment_terms.value_counts()
# Out:
# NAA8    15506
# NAH4    10524
# CA10     2968
# NAC6     1354
# NAM4     1033
# NAAX      950
# NAD1      781
# NAG2      744
# NAU5      712
# NA32      623
# NAGD      590
# NAX2      575
# NAM2      462
# NA10      348
# NAD5      259
# NAVF      227
# NAVE      212
# NAM1      207
# NAAW      164
# NAWU      116
# NAWN      103
# NAVR       83
# NAVQ       77
# NAWP       60
# NAUZ       46
# NA3B       42
# NAVM       38
# CA30       37
# NA38       36
# NACB       29
# NABG       28
# NAB1       24
# NAD4       18
# NA84       14
# NAVL       13
# C106       13
# NAVD       11
# NA9X       10
# NAUP       10
# NA3F        9
# NA31        6
# NA8Q        6
# BR56        5
# NA25        5
# BR12        4
# NATJ        4
# NATL        4
# NANC        4
# NAVC        3
# NATW        3
# NATX        3
# 90M7        3
# B052        3
# NAUW        3
# NATH        2
# NAUI        2
# CAX2        2
# NATV        2
# NAV2        1
# NAWM        1
# NATZ        1
# NAUX        1
# NAWK        1
# B112        1
# NACE        1
# NAM3        1
# CAB1        1
# Name: cust_payment_terms, dtype: int64

# %%
ref = dict(train_df['cust_payment_terms'].value_counts())
ref1 = dict(train_df['cust_payment_terms'].value_counts())
train_df['cust_payment_terms'] = train_df['cust_payment_terms'].map(ref)
test_df['cust_payment_terms'] = test_df['cust_payment_terms'].map(ref)

# %%
cust_number_encoder = LabelEncoder()
cust_number_encoder.fit(train_df['cust_number'])
train_df['cust_number'] = cust_number_encoder.transform(train_df['cust_number'])

cust_number_encoder1 = LabelEncoder()
cust_number_encoder1.fit(test_df['cust_number'])
test_df['cust_number'] = cust_number_encoder1.transform(test_df['cust_number'])

# %%
ref = dict(train_df['cust_number'].value_counts())
train_df['cust_number'] = train_df['cust_number'].map(ref)
ref1 = dict(test_df['cust_number'].value_counts())
test_df['cust_number'] = test_df['cust_number'].map(ref)

# %%
year_encoder = LabelEncoder()
year_encoder.fit(train_df['buisness_year'])
train_df['buisness_year'] = year_encoder.transform(train_df['buisness_year'])
year_encoder1 = LabelEncoder()
year_encoder1.fit(test_df['buisness_year'])
test_df['buisness_year'] = year_encoder1.transform(test_df['buisness_year'])

# %%
type_encoder = LabelEncoder()
type_encoder.fit(train_df['document type'])
train_df['document type'] = type_encoder.transform(train_df['document type'])
type_encoder1 = LabelEncoder()
type_encoder1.fit(test_df['document type'])
test_df['document type'] = type_encoder1.transform(test_df['document type'])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39129 entries, 380 to 35156
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_code         39129 non-null  int32
#  1   cust_number           39129 non-null  int64
#  2   name_customer         39129 non-null  object
#  3   clear_date            39129 non-null  datetime64[ns]
#  4   buisness_year         39129 non-null  int32
#  5   posting_date          39129 non-null  datetime64[ns]
#  6   document_create_date  39129 non-null  datetime64[ns]
#  7   due_in_date           39129 non-null  datetime64[ns]
#  8   invoice_currency      39129 non-null  object
#  9   document type         39129 non-null  int32
#  10  total_open_amount     39129 non-null  float64
#  11  baseline_create_date  39129 non-null  datetime64[ns]
#  12  cust_payment_terms    39129 non-null  int64
#  13  delay                 39129 non-null  int64
# dtypes: datetime64[ns](5), float64(1), int32(3), int64(3), object(2)
# memory usage: 4.0+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 4 to 49994
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_code         10000 non-null  int32
#  1   cust_number           10000 non-null  int64
#  2   name_customer         10000 non-null  object
#  3   clear_date            0 non-null      datetime64[ns]
#  4   buisness_year         10000 non-null  int32
#  5   posting_date          10000 non-null  datetime64[ns]
#  6   document_create_date  10000 non-null  datetime64[ns]
#  7   due_in_date           10000 non-null  datetime64[ns]
#  8   invoice_currency      10000 non-null  object
#  9   document type         10000 non-null  int32
#  10  total_open_amount     10000 non-null  float64
#  11  baseline_create_date  10000 non-null  datetime64[ns]
#  12  cust_payment_terms    9992 non-null   float64
# dtypes: datetime64[ns](5), float64(2), int32(3), int64(1), object(2)
# memory usage: 976.6+ KB

# %%
c = CurrencyRates()
train_df.loc[(train_df.invoice_currency != 'USD'), ['total_open_amount']] *= c.get_rate('CAD', 'USD')
train_df.replace(to_replace ="CAD", value ="USD",inplace=True)
test_df.loc[(test_df.invoice_currency != 'USD'), ['total_open_amount']] *= c.get_rate('CAD', 'USD')
test_df.replace(to_replace ="CAD", value ="USD",inplace=True)

# %%
train_df.nunique()
# Out:
# business_code               5
# cust_number               136
# name_customer            3912
# clear_date                400
# buisness_year               2
# posting_date              423
# document_create_date      426
# due_in_date               492
# invoice_currency            1
# document type               2
# total_open_amount       35535
# baseline_create_date      428
# cust_payment_terms         44
# delay                     192
# dtype: int64

# %%
train_df=train_df.drop(columns='invoice_currency',axis=1)
test_df=test_df.drop(columns='invoice_currency',axis=1)

# %%
train_df
# Out:
#        business_code  cust_number        name_customer clear_date  \
# 380                2           16           ASSOCI llc 2019-01-15
# 8784               2         8869          WAL-MAR llc 2019-01-15
# 9879               2         8869           WAL-MAR us 2019-01-15
# 15448              2          117                  FR  2019-01-14
# 14959              2         8869  WAL-MAR corporation 2019-01-10
# ...              ...          ...                  ...        ...
# 13758              2         8869  WAL-MAR corporation 2020-03-09
# 13125              2           14            ESSEX  us 2020-03-19
# 41892              2           56        BARGAIN  corp 2020-03-16
# 37929              2         1053        SA associates 2020-03-13
# 35156              2          890      COST associates 2020-03-12
#
#        buisness_year posting_date document_create_date due_in_date  \
# 380                0   2018-12-30           2018-12-29  2019-01-14
# 8784               0   2018-12-30           2018-12-29  2019-01-14
# 9879               0   2018-12-30           2018-12-29  2019-01-14
# 15448              0   2018-12-30           2018-12-29  2019-01-14
# 14959              0   2018-12-30           2018-12-29  2019-01-14
# ...              ...          ...                  ...         ...
# 13758              1   2020-02-26           2020-02-24  2020-03-12
# 13125              1   2020-02-26           2020-02-22  2020-03-12
# 41892              1   2020-02-27           2020-02-27  2020-03-13
# 37929              1   2020-02-27           2020-02-26  2020-03-13
# 35156              1   2020-02-27           2020-02-26  2020-03-13
#
#        document type  total_open_amount baseline_create_date  \
# 380                0           18655.77           2018-12-30
# 8784               0           20467.17           2018-12-30
# 9879               0            4439.84           2018-12-30
# 15448              0           66586.13           2018-12-30
# 14959              0            8730.88           2018-12-30
# ...              ...                ...                  ...
# 13758              0           16697.15           2020-02-26
# 13125              0           36435.85           2020-02-26
# 41892              0            3599.97           2020-02-27
# 37929              0            3396.48           2020-02-27
# 35156              0            5218.12           2020-02-27
#
#        cust_payment_terms  delay
# 380                 15506      1
# 8784                10524      1
# 9879                10524      1
# 15448               15506      0
# 14959               10524     -4
# ...                   ...    ...
# 13758               10524     -3
# 13125               15506      7
# 41892               15506      3
# 37929               10524      0
# 35156                 950     -1
#
# [39129 rows x 13 columns]

# %%
train_df['document_create_date_day'] = train_df['document_create_date'].dt.day
train_df['document_create_date_month'] = train_df['document_create_date'].dt.month
train_df['document_create_date_year'] = train_df['document_create_date'].dt.year
train_df['document_create_date_quarter']= train_df['document_create_date'].dt.quarter

test_df['document_create_date_day'] = test_df['document_create_date'].dt.day
test_df['document_create_date_month'] = test_df['document_create_date'].dt.month
test_df['document_create_date_year'] = test_df['document_create_date'].dt.year
test_df['document_create_date_quarter']= test_df['document_create_date'].dt.quarter

# %%
#checking corr of the dataset
corr = train_df.corr()
corr
# Out:
#                               business_code  cust_number  buisness_year  \
# business_code                      1.000000     0.122192       0.005754
# cust_number                        0.122192     1.000000       0.008760
# buisness_year                      0.005754     0.008760       1.000000
# document type                     -0.031919    -0.005895      -0.003887
# total_open_amount                 -0.123337    -0.138035      -0.005273
# cust_payment_terms                 0.203191     0.089729      -0.008787
# delay                             -0.085712    -0.156070      -0.017511
# document_create_date_day          -0.003145     0.011608       0.002093
# document_create_date_month        -0.012531     0.029907      -0.408394
# document_create_date_year          0.003622     0.003059       0.945075
# document_create_date_quarter      -0.011532     0.024496      -0.380736
#
#                               document type  total_open_amount  \
# business_code                     -0.031919          -0.123337
# cust_number                       -0.005895          -0.138035
# buisness_year                     -0.003887          -0.005273
# document type                      1.000000          -0.002569
# total_open_amount                 -0.002569           1.000000
# cust_payment_terms                -0.010543           0.073839
# delay                              0.190442          -0.001831
# document_create_date_day           0.015484           0.020027
# document_create_date_month        -0.007979           0.027257
# document_create_date_year         -0.003483          -0.003235
# document_create_date_quarter      -0.011482           0.028183
#
#                               cust_payment_terms     delay  \
# business_code                           0.203191 -0.085712
# cust_number                             0.089729 -0.156070
# buisness_year                          -0.008787 -0.017511
# document type                          -0.010543  0.190442
# total_open_amount                       0.073839 -0.001831
# cust_payment_terms                      1.000000 -0.073072
# delay                                  -0.073072  1.000000
# document_create_date_day                0.005026 -0.006862
# document_create_date_month              0.012052 -0.023345
# document_create_date_year              -0.012472 -0.019737
# document_create_date_quarter            0.014084 -0.020246
#
#                               document_create_date_day  \
# business_code                                -0.003145
# cust_number                                   0.011608
# buisness_year                                 0.002093
# document type                                 0.015484
# total_open_amount                             0.020027
# cust_payment_terms                            0.005026
# delay                                        -0.006862
# document_create_date_day                      1.000000
# document_create_date_month                   -0.003974
# document_create_date_year                    -0.058194
# document_create_date_quarter                  0.001304
#
#                               document_create_date_month  \
# business_code                                  -0.012531
# cust_number                                     0.029907
# buisness_year                                  -0.408394
# document type                                  -0.007979
# total_open_amount                               0.027257
# cust_payment_terms                              0.012052
# delay                                          -0.023345
# document_create_date_day                       -0.003974
# document_create_date_month                      1.000000
# document_create_date_year                      -0.472078
# document_create_date_quarter                    0.973643
#
#                               document_create_date_year  \
# business_code                                  0.003622
# cust_number                                    0.003059
# buisness_year                                  0.945075
# document type                                 -0.003483
# total_open_amount                             -0.003235
# cust_payment_terms                            -0.012472
# delay                                         -0.019737
# document_create_date_day                      -0.058194
# document_create_date_month                    -0.472078
# document_create_date_year                      1.000000
# document_create_date_quarter                  -0.434876
#
#                               document_create_date_quarter
# business_code                                    -0.011532
# cust_number                                       0.024496
# buisness_year                                    -0.380736
# document type                                    -0.011482
# total_open_amount                                 0.028183
# cust_payment_terms                                0.014084
# delay                                            -0.020246
# document_create_date_day                          0.001304
# document_create_date_month                        0.973643
# document_create_date_year                        -0.434876
# document_create_date_quarter                      1.000000

# %%
#heatmap 
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
#saving the data as train.csv
train_df.to_csv('train.csv')

# %%
#saving the data as test.csv
test_df.to_csv('test.csv')

# %%
#making a copy
X = train_df.drop(columns = ['delay']).copy()

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 4 to 49994
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   business_code                 10000 non-null  int32
#  1   cust_number                   10000 non-null  int64
#  2   name_customer                 10000 non-null  object
#  3   clear_date                    0 non-null      datetime64[ns]
#  4   buisness_year                 10000 non-null  int32
#  5   posting_date                  10000 non-null  datetime64[ns]
#  6   document_create_date          10000 non-null  datetime64[ns]
#  7   due_in_date                   10000 non-null  datetime64[ns]
#  8   document type                 10000 non-null  int32
#  9   total_open_amount             10000 non-null  float64
#  10  baseline_create_date          10000 non-null  datetime64[ns]
#  11  cust_payment_terms            9992 non-null   float64
#  12  document_create_date_day      10000 non-null  int64
#  13  document_create_date_month    10000 non-null  int64
#  14  document_create_date_year     10000 non-null  int64
#  15  document_create_date_quarter  10000 non-null  int64
# dtypes: datetime64[ns](5), float64(2), int32(3), int64(5), object(1)
# memory usage: 1.2+ MB

# %%
y = train_df['delay']

# %%
X_train, X_inter_test, y_train, y_inter_test = train_test_split(X, y, test_size=0.23, random_state=0, shuffle=False)

# %%
X_val, X_test, y_val, y_test = train_test_split(X_inter_test,y_inter_test, test_size=0.5,random_state=0,shuffle=False)

# %%
X_train.shape , X_val.shape , X_test.shape
# Out:
# ((30129, 16), (4500, 16), (4500, 16))

# %% [markdown]
# # EDA

# %%
sns.distplot(y_train)
# Out:
# <AxesSubplot:xlabel='delay', ylabel='Density'>

# %%
X_train.merge(y_train,on = X_train.index)
# Out:
#        key_0  business_code  cust_number        name_customer clear_date  \
# 0        380              2           16           ASSOCI llc 2019-01-15
# 1       8784              2         8869          WAL-MAR llc 2019-01-15
# 2       9879              2         8869           WAL-MAR us 2019-01-15
# 3      15448              2          117                  FR  2019-01-14
# 4      14959              2         8869  WAL-MAR corporation 2019-01-10
# ...      ...            ...          ...                  ...        ...
# 30124   8417              2         8869   WAL-MAR foundation 2019-11-18
# 30125  17104              2         8869      WAL-MAR systems 2019-11-21
# 30126  42854              2          259               DEC us 2019-11-08
# 30127  39152              2           79    ALBERT associates 2019-11-20
# 30128   6572              2          277       DEC associates 2019-11-18
#
#        buisness_year posting_date document_create_date due_in_date  \
# 0                  0   2018-12-30           2018-12-29  2019-01-14
# 1                  0   2018-12-30           2018-12-29  2019-01-14
# 2                  0   2018-12-30           2018-12-29  2019-01-14
# 3                  0   2018-12-30           2018-12-29  2019-01-14
# 4                  0   2018-12-30           2018-12-29  2019-01-14
# ...              ...          ...                  ...         ...
# 30124              0   2019-11-05           2019-11-03  2019-11-20
# 30125              0   2019-11-05           2019-11-05  2019-11-20
# 30126              0   2019-11-05           2019-11-05  2019-11-11
# 30127              0   2019-11-05           2019-11-05  2019-11-20
# 30128              0   2019-11-05           2019-11-05  2019-11-24
#
#        document type  total_open_amount baseline_create_date  \
# 0                  0           18655.77           2018-12-30
# 1                  0           20467.17           2018-12-30
# 2                  0            4439.84           2018-12-30
# 3                  0           66586.13           2018-12-30
# 4                  0            8730.88           2018-12-30
# ...              ...                ...                  ...
# 30124              0            3853.70           2019-11-05
# 30125              0           18576.20           2019-11-05
# 30126              0            5620.16           2019-11-01
# 30127              0           59495.70           2019-11-05
# 30128              0            2768.72           2019-11-01
#
#        cust_payment_terms  document_create_date_day  \
# 0                   15506                        29
# 1                   10524                        29
# 2                   10524                        29
# 3                   15506                        29
# 4                   10524                        29
# ...                   ...                       ...
# 30124               10524                         3
# 30125               10524                         5
# 30126                 462                         5
# 30127               15506                         5
# 30128                1033                         5
#
#        document_create_date_month  document_create_date_year  \
# 0                              12                       2018
# 1                              12                       2018
# 2                              12                       2018
# 3                              12                       2018
# 4                              12                       2018
# ...                           ...                        ...
# 30124                          11                       2019
# 30125                          11                       2019
# 30126                          11                       2019
# 30127                          11                       2019
# 30128                          11                       2019
#
#        document_create_date_quarter  delay
# 0                                 4      1
# 1                                 4      1
# 2                                 4      1
# 3                                 4      0
# 4                                 4     -4
# ...                             ...    ...
# 30124                             4     -2
# 30125                             4      1
# 30126                             4     -3
# 30127                             4      0
# 30128                             4     -6
#
# [30129 rows x 18 columns]

# %%
sns.scatterplot(data=X_train.merge(y_train,on = X_train.index), x="delay", y="posting_date")
# Out:
# <AxesSubplot:xlabel='delay', ylabel='posting_date'>

# %%
X_train.drop(columns = ['name_customer'],axis=1,inplace=True)

# %%
X_val.drop(columns = ['name_customer'],axis=1,inplace=True)

# %%
X_test.drop(columns = ['name_customer'],axis=1,inplace=True)

# %%
test_df.drop(columns = ['name_customer'],axis=1,inplace=True)

# %%
plt.figure(figsize=(5,5))
plt.figure(1)
sns.distplot(X_train['cust_payment_terms'],color='blue')
# Out:
# <AxesSubplot:xlabel='cust_payment_terms', ylabel='Density'>

# %% [markdown]
# # Feature Selection

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(X_train.merge(y_train , on = X_train.index ).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30129 entries, 380 to 6572
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   business_code                 30129 non-null  int32
#  1   cust_number                   30129 non-null  int64
#  2   clear_date                    30129 non-null  datetime64[ns]
#  3   buisness_year                 30129 non-null  int32
#  4   posting_date                  30129 non-null  datetime64[ns]
#  5   document_create_date          30129 non-null  datetime64[ns]
#  6   due_in_date                   30129 non-null  datetime64[ns]
#  7   document type                 30129 non-null  int32
#  8   total_open_amount             30129 non-null  float64
#  9   baseline_create_date          30129 non-null  datetime64[ns]
#  10  cust_payment_terms            30129 non-null  int64
#  11  document_create_date_day      30129 non-null  int64
#  12  document_create_date_month    30129 non-null  int64
#  13  document_create_date_year     30129 non-null  int64
#  14  document_create_date_quarter  30129 non-null  int64
# dtypes: datetime64[ns](5), float64(1), int32(3), int64(6)
# memory usage: 3.3 MB

# %%
X_train=X_train.drop(columns=['document type','buisness_year','clear_date','posting_date','document_create_date','due_in_date','baseline_create_date'],axis=1)

# %%
X_test=X_test.drop(columns=['document type','buisness_year','clear_date','posting_date','document_create_date','due_in_date','baseline_create_date'],axis=1)

# %%
X_val=X_val.drop(columns=['document type','buisness_year','clear_date','posting_date','document_create_date','due_in_date','baseline_create_date'],axis=1)

# %%
final_test_df=test_df.drop(columns=['document type','buisness_year','clear_date','posting_date','document_create_date','due_in_date','baseline_create_date'],axis=1)

# %%
X_train.nunique()
# Out:
# business_code                       5
# cust_number                       136
# total_open_amount               27481
# cust_payment_terms                 44
# document_create_date_day           31
# document_create_date_month         12
# document_create_date_year           2
# document_create_date_quarter        4
# dtype: int64

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
base_model = LinearRegression()
base_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = base_model.predict(X_val)
y_predict
# Out:
# array([ 1.24816142,  1.17954665,  2.95918516, ...,  0.03342693,
#        -0.80819815, -0.20113749])

# %%
y_predict = y_predict.astype(int)
y_predict
# Out:
# array([1, 1, 2, ..., 0, 0, 0])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_val, y_predict, squared=False)
# Out:
# 6.097303593483853

# %% [markdown]
# # Decision tree regressor

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0 , max_depth=5)

# %%
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=0)

# %%
y_predict2 = regressor.predict(X_val)
y_predict2
# Out:
# array([0.80673434, 0.80673434, 0.80673434, ..., 0.80673434, 0.80673434,
#        0.80673434])

# %%
y_predict2 = y_predict2.astype(int)
y_predict2
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
mse=mean_squared_error(y_val, y_predict2, squared=False)
mse
# Out:
# 4.717508758750628

# %%
import math

rmse = math. sqrt(mse)
print(rmse)
# Out:
# 2.1719826792013395

# %%
y_predict_test = regressor.predict(X_test)
mean_squared_error(y_test, y_predict_test, squared=False)
# Out:
# 7.705982814475331

# %% [markdown]
# # Accuracy Checker

# %%
from sklearn.ensemble import RandomForestRegressor

import random
random_model = RandomForestRegressor(n_estimators=500)

random_model.fit(X_train, y_train)

y_pred2 = random_model.predict(X_test).astype(int)
#Checking the accuracy
random_model_accuracy = round(random_model.score(X_train, y_train)*100,2)
print(round(random_model_accuracy,2),'%')
# Out:
# 91.65 %

# %%
final_test_df
# Out:
#        business_code  cust_number  total_open_amount  cust_payment_terms  \
# 4                  2            1           95651.82             15506.0
# 13                 2           10           12446.28               462.0
# 22                 2            5           11889.49             15506.0
# 29                 2            1           20691.83             10524.0
# 45                 2            1            8058.89               590.0
# ...              ...          ...                ...                 ...
# 49982              2            5             132.72             15506.0
# 49985              2            1           53216.50             10524.0
# 49987              2            1            1322.22             10524.0
# 49988              2            1           73209.62             15506.0
# 49994              2            4           18815.63             15506.0
#
#        document_create_date_day  document_create_date_month  \
# 4                            11                           4
# 13                            7                           3
# 22                            6                           4
# 29                           21                           3
# 45                           31                           3
# ...                         ...                         ...
# 49982                        27                           4
# 49985                        22                           3
# 49987                        18                           3
# 49988                         3                           3
# 49994                        13                           4
#
#        document_create_date_year  document_create_date_quarter
# 4                           2020                             2
# 13                          2020                             1
# 22                          2020                             2
# 29                          2020                             1
# 45                          2020                             1
# ...                          ...                           ...
# 49982                       2020                             2
# 49985                       2020                             1
# 49987                       2020                             1
# 49988                       2020                             1
# 49994                       2020                             2
#
# [10000 rows x 8 columns]

# %%
null = final_test_df.isnull().sum().to_frame(name = 'Null_Count')
null = null[null['Null_Count']>0]
null_features = null.index
null
# Out:
#                     Null_Count
# cust_payment_terms           8

# %%
final_test_df=final_test_df.dropna()

# %%
#predict delay for final test data
final_test_df['delay']=random_model.predict(final_test_df).astype(int)

# %%
final_test_df
# Out:
#        business_code  cust_number  total_open_amount  cust_payment_terms  \
# 4                  2            1           95651.82             15506.0
# 13                 2           10           12446.28               462.0
# 22                 2            5           11889.49             15506.0
# 29                 2            1           20691.83             10524.0
# 45                 2            1            8058.89               590.0
# ...              ...          ...                ...                 ...
# 49982              2            5             132.72             15506.0
# 49985              2            1           53216.50             10524.0
# 49987              2            1            1322.22             10524.0
# 49988              2            1           73209.62             15506.0
# 49994              2            4           18815.63             15506.0
#
#        document_create_date_day  document_create_date_month  \
# 4                            11                           4
# 13                            7                           3
# 22                            6                           4
# 29                           21                           3
# 45                           31                           3
# ...                         ...                         ...
# 49982                        27                           4
# 49985                        22                           3
# 49987                        18                           3
# 49988                         3                           3
# 49994                        13                           4
#
#        document_create_date_year  document_create_date_quarter  delay
# 4                           2020                             2     -1
# 13                          2020                             1      2
# 22                          2020                             2      1
# 29                          2020                             1      0
# 45                          2020                             1    -29
# ...                          ...                           ...    ...
# 49982                       2020                             2      4
# 49985                       2020                             1      0
# 49987                       2020                             1      0
# 49988                       2020                             1     -2
# 49994                       2020                             2      1
#
# [9992 rows x 9 columns]

# %%
#creating payment Date Prediction
final_test_df['Payment date prediction']=test_df['due_in_date']+pd.to_timedelta(final_test_df['delay'],unit='d')

# %%
final_test_df
# Out:
#        business_code  cust_number  total_open_amount  cust_payment_terms  \
# 4                  2            1           95651.82             15506.0
# 13                 2           10           12446.28               462.0
# 22                 2            5           11889.49             15506.0
# 29                 2            1           20691.83             10524.0
# 45                 2            1            8058.89               590.0
# ...              ...          ...                ...                 ...
# 49982              2            5             132.72             15506.0
# 49985              2            1           53216.50             10524.0
# 49987              2            1            1322.22             10524.0
# 49988              2            1           73209.62             15506.0
# 49994              2            4           18815.63             15506.0
#
#        document_create_date_day  document_create_date_month  \
# 4                            11                           4
# 13                            7                           3
# 22                            6                           4
# 29                           21                           3
# 45                           31                           3
# ...                         ...                         ...
# 49982                        27                           4
# 49985                        22                           3
# 49987                        18                           3
# 49988                         3                           3
# 49994                        13                           4
#
#        document_create_date_year  document_create_date_quarter  delay  \
# 4                           2020                             2     -1
# 13                          2020                             1      2
# 22                          2020                             2      1
# 29                          2020                             1      0
# 45                          2020                             1    -29
# ...                          ...                           ...    ...
# 49982                       2020                             2      4
# 49985                       2020                             1      0
# 49987                       2020                             1      0
# 49988                       2020                             1     -2
# 49994                       2020                             2      1
#
#       Payment date prediction
# 4                  2020-04-27
# 13                 2020-03-13
# 22                 2020-04-22
# 29                 2020-04-06
# 45                 2020-05-07
# ...                       ...
# 49982              2020-05-15
# 49985              2020-04-07
# 49987              2020-04-03
# 49988              2020-03-16
# 49994              2020-04-30
#
# [9992 rows x 10 columns]

# %% [markdown]
# # Bucketisation

# %%
aging_bucket = []
for x in final_test_df['delay']:
    if x<=0:
        aging_bucket.append("0 days")
        
    elif x<=15:
        aging_bucket.append("1-15days")
    elif x<=30:
        aging_bucket.append("16-30days")
    elif x<=45:
        aging_bucket.append("31-45days")
    elif x<=60:
        aging_bucket.append("46-60days")
    else:
        aging_bucket.append("Greater than 60 days")
final_test_df['Aging_Bucket']=aging_bucket

# %%
final_test_df
# Out:
#        business_code  cust_number  total_open_amount  cust_payment_terms  \
# 4                  2            1           95651.82             15506.0
# 13                 2           10           12446.28               462.0
# 22                 2            5           11889.49             15506.0
# 29                 2            1           20691.83             10524.0
# 45                 2            1            8058.89               590.0
# ...              ...          ...                ...                 ...
# 49982              2            5             132.72             15506.0
# 49985              2            1           53216.50             10524.0
# 49987              2            1            1322.22             10524.0
# 49988              2            1           73209.62             15506.0
# 49994              2            4           18815.63             15506.0
#
#        document_create_date_day  document_create_date_month  \
# 4                            11                           4
# 13                            7                           3
# 22                            6                           4
# 29                           21                           3
# 45                           31                           3
# ...                         ...                         ...
# 49982                        27                           4
# 49985                        22                           3
# 49987                        18                           3
# 49988                         3                           3
# 49994                        13                           4
#
#        document_create_date_year  document_create_date_quarter  delay  \
# 4                           2020                             2     -1
# 13                          2020                             1      2
# 22                          2020                             2      1
# 29                          2020                             1      0
# 45                          2020                             1    -29
# ...                          ...                           ...    ...
# 49982                       2020                             2      4
# 49985                       2020                             1      0
# 49987                       2020                             1      0
# 49988                       2020                             1     -2
# 49994                       2020                             2      1
#
#       Payment date prediction Aging_Bucket
# 4                  2020-04-27       0 days
# 13                 2020-03-13     1-15days
# 22                 2020-04-22     1-15days
# 29                 2020-04-06       0 days
# 45                 2020-05-07       0 days
# ...                       ...          ...
# 49982              2020-05-15     1-15days
# 49985              2020-04-07       0 days
# 49987              2020-04-03       0 days
# 49988              2020-03-16       0 days
# 49994              2020-04-30     1-15days
#
# [9992 rows x 11 columns]

# %%
final_test_df=final_test_df.to_csv("Train1.csv")

# %%
#reading the Train.csv dataset
data1=pd.read_csv('Train1.csv')
final_test_df=pd.DataFrame(data1)
final_test_df
# Out:
#       Unnamed: 0  business_code  cust_number  total_open_amount  \
# 0              4              2            1           95651.82
# 1             13              2           10           12446.28
# 2             22              2            5           11889.49
# 3             29              2            1           20691.83
# 4             45              2            1            8058.89
# ...          ...            ...          ...                ...
# 9987       49982              2            5             132.72
# 9988       49985              2            1           53216.50
# 9989       49987              2            1            1322.22
# 9990       49988              2            1           73209.62
# 9991       49994              2            4           18815.63
#
#       cust_payment_terms  document_create_date_day  \
# 0                15506.0                        11
# 1                  462.0                         7
# 2                15506.0                         6
# 3                10524.0                        21
# 4                  590.0                        31
# ...                  ...                       ...
# 9987             15506.0                        27
# 9988             10524.0                        22
# 9989             10524.0                        18
# 9990             15506.0                         3
# 9991             15506.0                        13
#
#       document_create_date_month  document_create_date_year  \
# 0                              4                       2020
# 1                              3                       2020
# 2                              4                       2020
# 3                              3                       2020
# 4                              3                       2020
# ...                          ...                        ...
# 9987                           4                       2020
# 9988                           3                       2020
# 9989                           3                       2020
# 9990                           3                       2020
# 9991                           4                       2020
#
#       document_create_date_quarter  delay Payment date prediction Aging_Bucket
# 0                                2     -1              2020-04-27       0 days
# 1                                1      2              2020-03-13     1-15days
# 2                                2      1              2020-04-22     1-15days
# 3                                1      0              2020-04-06       0 days
# 4                                1    -29              2020-05-07       0 days
# ...                            ...    ...                     ...          ...
# 9987                             2      4              2020-05-15     1-15days
# 9988                             1      0              2020-04-07       0 days
# 9989                             1      0              2020-04-03       0 days
# 9990                             1     -2              2020-03-16       0 days
# 9991                             2      1              2020-04-30     1-15days
#
# [9992 rows x 12 columns]

# %%
#counting the values 
final_test_df.Aging_Bucket.value_counts()
# Out:
# 0 days                  5794
# 1-15days                3922
# 16-30days                169
# Greater than 60 days      68
# 46-60days                 22
# 31-45days                 17
# Name: Aging_Bucket, dtype: int64

# %%
df4=pd.DataFrame(data)

# %%
df4
# Out:
#       business_code cust_number        name_customer           clear_date  \
# 0              U001  0200769623      WAL-MAR systems  2019-04-19 00:00:00
# 1              U001  0200124634   BAKEMAR associates  2020-03-11 00:00:00
# 2              U001  0200759878                SA us  2019-01-28 00:00:00
# 3              U001  0200769623   WAL-MAR associates  2019-01-25 00:00:00
# 4              U001  0100031704          DELHAIZE in                  NaN
# ...             ...         ...                  ...                  ...
# 49995          U001  0200769623  WAL-MAR corporation  2019-05-17 00:00:00
# 49996          U001  0200777735     NASH  foundation  2020-01-21 00:00:00
# 49997          U001  0200965912          C&S W trust  2019-12-02 00:00:00
# 49998          U001  0200729942              SA corp  2019-10-29 00:00:00
# 49999          U001  0200762950            HAR trust  2019-12-20 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2019.0  1.929075e+09   2019-04-03              20190403
# 1             2020.0  1.930573e+09   2020-02-26              20200226
# 2             2019.0  1.928567e+09   2019-01-05              20190104
# 3             2019.0  1.928619e+09   2019-01-15              20190114
# 4             2020.0  1.930778e+09   2020-04-13              20200411
# ...              ...           ...          ...                   ...
# 49995         2019.0  1.929270e+09   2019-05-07              20190506
# 49996         2020.0  1.930363e+09   2020-01-06              20200106
# 49997         2019.0  1.930153e+09   2019-11-14              20191114
# 49998         2019.0  1.930013e+09   2019-10-14              20191014
# 49999         2019.0  1.930219e+09   2019-12-06              20191205
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20190403   20190418.0              USD            RV
# 1                    20200226   20200307.0              USD            RV
# 2                    20190105   20190120.0              USD            RV
# 3                    20190115   20190130.0              USD            RV
# 4                    20200413   20200428.0              USD            RV
# ...                       ...          ...              ...           ...
# 49995                20190507   20190522.0              USD            RV
# 49996                20200106   20200121.0              USD            RV
# 49997                20191114   20191129.0              USD            RV
# 49998                20191014   20191029.0              USD            RV
# 49999                20191206   20191221.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 0             1.0            NaN           55602.94            20190403.0
# 1             1.0            NaN            8345.60            20200226.0
# 2             1.0            NaN           13768.73            20190105.0
# 3             1.0            NaN            7463.23            20190115.0
# 4             1.0            NaN           95651.82            20200413.0
# ...           ...            ...                ...                   ...
# 49995         1.0            NaN            6532.60            20190507.0
# 49996         1.0            NaN           84123.80            20200106.0
# 49997         1.0            NaN           22325.58            20191114.0
# 49998         1.0            NaN           25563.51            20191014.0
# 49999         1.0            NaN          161070.91            20191206.0
#
#       cust_payment_terms    invoice_id  isOpen
# 0                   NAH4  1.929075e+09       0
# 1                   NA10  1.930573e+09       0
# 2                   NAH4  1.928567e+09       0
# 3                   NAH4  1.928619e+09       0
# 4                   NAA8  1.930778e+09       1
# ...                  ...           ...     ...
# 49995               NAH4  1.929270e+09       0
# 49996               NAA8  1.930363e+09       0
# 49997               NAC6  1.930153e+09       0
# 49998               NAA8  1.930013e+09       0
# 49999               NAA8  1.930219e+09       0
#
# [50000 rows x 19 columns]

# %%
df4=df4.to_csv("Train2.csv")
data2=pd.read_csv('Train2.csv')
df4=pd.DataFrame(data2)
df4
# Out:
#        Unnamed: 0 business_code cust_number        name_customer  \
# 0               0          U001  0200769623      WAL-MAR systems
# 1               1          U001  0200124634   BAKEMAR associates
# 2               2          U001  0200759878                SA us
# 3               3          U001  0200769623   WAL-MAR associates
# 4               4          U001  0100031704          DELHAIZE in
# ...           ...           ...         ...                  ...
# 49995       49995          U001  0200769623  WAL-MAR corporation
# 49996       49996          U001  0200777735     NASH  foundation
# 49997       49997          U001  0200965912          C&S W trust
# 49998       49998          U001  0200729942              SA corp
# 49999       49999          U001  0200762950            HAR trust
#
#                 clear_date  buisness_year        doc_id posting_date  \
# 0      2019-04-19 00:00:00         2019.0  1.929075e+09   2019-04-03
# 1      2020-03-11 00:00:00         2020.0  1.930573e+09   2020-02-26
# 2      2019-01-28 00:00:00         2019.0  1.928567e+09   2019-01-05
# 3      2019-01-25 00:00:00         2019.0  1.928619e+09   2019-01-15
# 4                      NaN         2020.0  1.930778e+09   2020-04-13
# ...                    ...            ...           ...          ...
# 49995  2019-05-17 00:00:00         2019.0  1.929270e+09   2019-05-07
# 49996  2020-01-21 00:00:00         2020.0  1.930363e+09   2020-01-06
# 49997  2019-12-02 00:00:00         2019.0  1.930153e+09   2019-11-14
# 49998  2019-10-29 00:00:00         2019.0  1.930013e+09   2019-10-14
# 49999  2019-12-20 00:00:00         2019.0  1.930219e+09   2019-12-06
#
#        document_create_date  document_create_date.1  due_in_date  \
# 0                  20190403                20190403   20190418.0
# 1                  20200226                20200226   20200307.0
# 2                  20190104                20190105   20190120.0
# 3                  20190114                20190115   20190130.0
# 4                  20200411                20200413   20200428.0
# ...                     ...                     ...          ...
# 49995              20190506                20190507   20190522.0
# 49996              20200106                20200106   20200121.0
# 49997              20191114                20191114   20191129.0
# 49998              20191014                20191014   20191029.0
# 49999              20191205                20191206   20191221.0
#
#       invoice_currency document type  posting_id  area_business  \
# 0                  USD            RV         1.0            NaN
# 1                  USD            RV         1.0            NaN
# 2                  USD            RV         1.0            NaN
# 3                  USD            RV         1.0            NaN
# 4                  USD            RV         1.0            NaN
# ...                ...           ...         ...            ...
# 49995              USD            RV         1.0            NaN
# 49996              USD            RV         1.0            NaN
# 49997              USD            RV         1.0            NaN
# 49998              USD            RV         1.0            NaN
# 49999              USD            RV         1.0            NaN
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 0               55602.94            20190403.0               NAH4
# 1                8345.60            20200226.0               NA10
# 2               13768.73            20190105.0               NAH4
# 3                7463.23            20190115.0               NAH4
# 4               95651.82            20200413.0               NAA8
# ...                  ...                   ...                ...
# 49995            6532.60            20190507.0               NAH4
# 49996           84123.80            20200106.0               NAA8
# 49997           22325.58            20191114.0               NAC6
# 49998           25563.51            20191014.0               NAA8
# 49999          161070.91            20191206.0               NAA8
#
#          invoice_id  isOpen
# 0      1.929075e+09       0
# 1      1.930573e+09       0
# 2      1.928567e+09       0
# 3      1.928619e+09       0
# 4      1.930778e+09       1
# ...             ...     ...
# 49995  1.929270e+09       0
# 49996  1.930363e+09       0
# 49997  1.930153e+09       0
# 49998  1.930013e+09       0
# 49999  1.930219e+09       0
#
# [50000 rows x 20 columns]

# %%
final_test_df
# Out:
#       Unnamed: 0  business_code  cust_number  total_open_amount  \
# 0              4              2            1           95651.82
# 1             13              2           10           12446.28
# 2             22              2            5           11889.49
# 3             29              2            1           20691.83
# 4             45              2            1            8058.89
# ...          ...            ...          ...                ...
# 9987       49982              2            5             132.72
# 9988       49985              2            1           53216.50
# 9989       49987              2            1            1322.22
# 9990       49988              2            1           73209.62
# 9991       49994              2            4           18815.63
#
#       cust_payment_terms  document_create_date_day  \
# 0                15506.0                        11
# 1                  462.0                         7
# 2                15506.0                         6
# 3                10524.0                        21
# 4                  590.0                        31
# ...                  ...                       ...
# 9987             15506.0                        27
# 9988             10524.0                        22
# 9989             10524.0                        18
# 9990             15506.0                         3
# 9991             15506.0                        13
#
#       document_create_date_month  document_create_date_year  \
# 0                              4                       2020
# 1                              3                       2020
# 2                              4                       2020
# 3                              3                       2020
# 4                              3                       2020
# ...                          ...                        ...
# 9987                           4                       2020
# 9988                           3                       2020
# 9989                           3                       2020
# 9990                           3                       2020
# 9991                           4                       2020
#
#       document_create_date_quarter  delay Payment date prediction Aging_Bucket
# 0                                2     -1              2020-04-27       0 days
# 1                                1      2              2020-03-13     1-15days
# 2                                2      1              2020-04-22     1-15days
# 3                                1      0              2020-04-06       0 days
# 4                                1    -29              2020-05-07       0 days
# ...                            ...    ...                     ...          ...
# 9987                             2      4              2020-05-15     1-15days
# 9988                             1      0              2020-04-07       0 days
# 9989                             1      0              2020-04-03       0 days
# 9990                             1     -2              2020-03-16       0 days
# 9991                             2      1              2020-04-30     1-15days
#
# [9992 rows x 12 columns]

# %%
df_inner = pd.merge(final_test_df, df4, on='Unnamed: 0', how='inner')

df_inner
# Out:
#       Unnamed: 0  business_code_x  cust_number_x  total_open_amount_x  \
# 0              4                2              1             95651.82
# 1             13                2             10             12446.28
# 2             22                2              5             11889.49
# 3             29                2              1             20691.83
# 4             45                2              1              8058.89
# ...          ...              ...            ...                  ...
# 9987       49982                2              5               132.72
# 9988       49985                2              1             53216.50
# 9989       49987                2              1              1322.22
# 9990       49988                2              1             73209.62
# 9991       49994                2              4             18815.63
#
#       cust_payment_terms_x  document_create_date_day  \
# 0                  15506.0                        11
# 1                    462.0                         7
# 2                  15506.0                         6
# 3                  10524.0                        21
# 4                    590.0                        31
# ...                    ...                       ...
# 9987               15506.0                        27
# 9988               10524.0                        22
# 9989               10524.0                        18
# 9990               15506.0                         3
# 9991               15506.0                        13
#
#       document_create_date_month  document_create_date_year  \
# 0                              4                       2020
# 1                              3                       2020
# 2                              4                       2020
# 3                              3                       2020
# 4                              3                       2020
# ...                          ...                        ...
# 9987                           4                       2020
# 9988                           3                       2020
# 9989                           3                       2020
# 9990                           3                       2020
# 9991                           4                       2020
#
#       document_create_date_quarter  delay Payment date prediction  \
# 0                                2     -1              2020-04-27
# 1                                1      2              2020-03-13
# 2                                2      1              2020-04-22
# 3                                1      0              2020-04-06
# 4                                1    -29              2020-05-07
# ...                            ...    ...                     ...
# 9987                             2      4              2020-05-15
# 9988                             1      0              2020-04-07
# 9989                             1      0              2020-04-03
# 9990                             1     -2              2020-03-16
# 9991                             2      1              2020-04-30
#
#      Aging_Bucket business_code_y cust_number_y    name_customer clear_date  \
# 0          0 days            U001    0100031704      DELHAIZE in        NaN
# 1        1-15days            U001    0200803720      DEC systems        NaN
# 2        1-15days            U001    0200701314          MBM  co        NaN
# 3          0 days            U001    0200769623       WAL-MAR us        NaN
# 4          0 days            U001    0200769623    WAL-MAR trust        NaN
# ...           ...             ...           ...              ...        ...
# 9987     1-15days            U001    0200726979    BJ'S  systems        NaN
# 9988       0 days            U001     200769623  WAL-MAR systems        NaN
# 9989       0 days            U001    0200769623     WAL-MAR corp        NaN
# 9990       0 days            U001    0200792734          MDV/ co        NaN
# 9991     1-15days            U001    0100036039            GI us        NaN
#
#       buisness_year        doc_id posting_date  document_create_date  \
# 0            2020.0  1.930778e+09   2020-04-13              20200411
# 1            2020.0  1.930618e+09   2020-03-07              20200307
# 2            2020.0  1.930751e+09   2020-04-06              20200406
# 3            2020.0  1.930684e+09   2020-03-22              20200321
# 4            2020.0  1.930726e+09   2020-04-01              20200331
# ...             ...           ...          ...                   ...
# 9987         2020.0  1.930828e+09   2020-04-26              20200427
# 9988         2020.0  1.930686e+09   2020-03-23              20200322
# 9989         2020.0  1.930666e+09   2020-03-19              20200318
# 9990         2020.0  1.930593e+09   2020-03-03              20200303
# 9991         2020.0  1.930781e+09   2020-04-14              20200413
#
#       document_create_date.1  due_in_date invoice_currency document type  \
# 0                   20200413   20200428.0              USD            RV
# 1                   20200307   20200311.0              USD            RV
# 2                   20200406   20200421.0              USD            RV
# 3                   20200322   20200406.0              USD            RV
# 4                   20200401   20200605.0              USD            RV
# ...                      ...          ...              ...           ...
# 9987                20200426   20200511.0              USD            RV
# 9988                20200323   20200407.0              USD            RV
# 9989                20200319   20200403.0              USD            RV
# 9990                20200303   20200318.0              USD            RV
# 9991                20200414   20200429.0              USD            RV
#
#       posting_id  area_business  total_open_amount_y  baseline_create_date  \
# 0            1.0            NaN             95651.82            20200413.0
# 1            1.0            NaN             12446.28            20200301.0
# 2            1.0            NaN             11889.49            20200406.0
# 3            1.0            NaN             20691.83            20200322.0
# 4            1.0            NaN              8058.89            20200401.0
# ...          ...            ...                  ...                   ...
# 9987         1.0            NaN               132.72            20200426.0
# 9988         1.0            NaN             53216.50            20200323.0
# 9989         1.0            NaN              1322.22            20200319.0
# 9990         1.0            NaN             73209.62            20200303.0
# 9991         1.0            NaN             18815.63            20200414.0
#
#      cust_payment_terms_y    invoice_id  isOpen
# 0                    NAA8  1.930778e+09       1
# 1                    NAM2  1.930618e+09       1
# 2                    NAA8  1.930751e+09       1
# 3                    NAH4  1.930684e+09       1
# 4                    NAGD  1.930726e+09       1
# ...                   ...           ...     ...
# 9987                 NAA8  1.930828e+09       1
# 9988                 NAH4  1.930686e+09       1
# 9989                 NAH4  1.930666e+09       1
# 9990                 NAA8  1.930593e+09       1
# 9991                 NAA8  1.930781e+09       1
#
# [9992 rows x 31 columns]

# %%
df5=df_inner.to_csv("Train3.csv")
data3=pd.read_csv('Train3.csv')
df5=pd.DataFrame(data3)
df5
# Out:
#       Unnamed: 0  Unnamed: 0.1  business_code_x  cust_number_x  \
# 0              0             4                2              1
# 1              1            13                2             10
# 2              2            22                2              5
# 3              3            29                2              1
# 4              4            45                2              1
# ...          ...           ...              ...            ...
# 9987        9987         49982                2              5
# 9988        9988         49985                2              1
# 9989        9989         49987                2              1
# 9990        9990         49988                2              1
# 9991        9991         49994                2              4
#
#       total_open_amount_x  cust_payment_terms_x  document_create_date_day  \
# 0                95651.82               15506.0                        11
# 1                12446.28                 462.0                         7
# 2                11889.49               15506.0                         6
# 3                20691.83               10524.0                        21
# 4                 8058.89                 590.0                        31
# ...                   ...                   ...                       ...
# 9987               132.72               15506.0                        27
# 9988             53216.50               10524.0                        22
# 9989              1322.22               10524.0                        18
# 9990             73209.62               15506.0                         3
# 9991             18815.63               15506.0                        13
#
#       document_create_date_month  document_create_date_year  \
# 0                              4                       2020
# 1                              3                       2020
# 2                              4                       2020
# 3                              3                       2020
# 4                              3                       2020
# ...                          ...                        ...
# 9987                           4                       2020
# 9988                           3                       2020
# 9989                           3                       2020
# 9990                           3                       2020
# 9991                           4                       2020
#
#       document_create_date_quarter  delay Payment date prediction  \
# 0                                2     -1              2020-04-27
# 1                                1      2              2020-03-13
# 2                                2      1              2020-04-22
# 3                                1      0              2020-04-06
# 4                                1    -29              2020-05-07
# ...                            ...    ...                     ...
# 9987                             2      4              2020-05-15
# 9988                             1      0              2020-04-07
# 9989                             1      0              2020-04-03
# 9990                             1     -2              2020-03-16
# 9991                             2      1              2020-04-30
#
#      Aging_Bucket business_code_y cust_number_y    name_customer  clear_date  \
# 0          0 days            U001    0100031704      DELHAIZE in         NaN
# 1        1-15days            U001    0200803720      DEC systems         NaN
# 2        1-15days            U001    0200701314          MBM  co         NaN
# 3          0 days            U001    0200769623       WAL-MAR us         NaN
# 4          0 days            U001    0200769623    WAL-MAR trust         NaN
# ...           ...             ...           ...              ...         ...
# 9987     1-15days            U001    0200726979    BJ'S  systems         NaN
# 9988       0 days            U001     200769623  WAL-MAR systems         NaN
# 9989       0 days            U001    0200769623     WAL-MAR corp         NaN
# 9990       0 days            U001    0200792734          MDV/ co         NaN
# 9991     1-15days            U001    0100036039            GI us         NaN
#
#       buisness_year        doc_id posting_date  document_create_date  \
# 0            2020.0  1.930778e+09   2020-04-13              20200411
# 1            2020.0  1.930618e+09   2020-03-07              20200307
# 2            2020.0  1.930751e+09   2020-04-06              20200406
# 3            2020.0  1.930684e+09   2020-03-22              20200321
# 4            2020.0  1.930726e+09   2020-04-01              20200331
# ...             ...           ...          ...                   ...
# 9987         2020.0  1.930828e+09   2020-04-26              20200427
# 9988         2020.0  1.930686e+09   2020-03-23              20200322
# 9989         2020.0  1.930666e+09   2020-03-19              20200318
# 9990         2020.0  1.930593e+09   2020-03-03              20200303
# 9991         2020.0  1.930781e+09   2020-04-14              20200413
#
#       document_create_date.1  due_in_date invoice_currency document type  \
# 0                   20200413   20200428.0              USD            RV
# 1                   20200307   20200311.0              USD            RV
# 2                   20200406   20200421.0              USD            RV
# 3                   20200322   20200406.0              USD            RV
# 4                   20200401   20200605.0              USD            RV
# ...                      ...          ...              ...           ...
# 9987                20200426   20200511.0              USD            RV
# 9988                20200323   20200407.0              USD            RV
# 9989                20200319   20200403.0              USD            RV
# 9990                20200303   20200318.0              USD            RV
# 9991                20200414   20200429.0              USD            RV
#
#       posting_id  area_business  total_open_amount_y  baseline_create_date  \
# 0            1.0            NaN             95651.82            20200413.0
# 1            1.0            NaN             12446.28            20200301.0
# 2            1.0            NaN             11889.49            20200406.0
# 3            1.0            NaN             20691.83            20200322.0
# 4            1.0            NaN              8058.89            20200401.0
# ...          ...            ...                  ...                   ...
# 9987         1.0            NaN               132.72            20200426.0
# 9988         1.0            NaN             53216.50            20200323.0
# 9989         1.0            NaN              1322.22            20200319.0
# 9990         1.0            NaN             73209.62            20200303.0
# 9991         1.0            NaN             18815.63            20200414.0
#
#      cust_payment_terms_y    invoice_id  isOpen
# 0                    NAA8  1.930778e+09       1
# 1                    NAM2  1.930618e+09       1
# 2                    NAA8  1.930751e+09       1
# 3                    NAH4  1.930684e+09       1
# 4                    NAGD  1.930726e+09       1
# ...                   ...           ...     ...
# 9987                 NAA8  1.930828e+09       1
# 9988                 NAH4  1.930686e+09       1
# 9989                 NAH4  1.930666e+09       1
# 9990                 NAA8  1.930593e+09       1
# 9991                 NAA8  1.930781e+09       1
#
# [9992 rows x 32 columns]

# %%
df5['document_create_date']=pd.to_datetime(df5['document_create_date'], format='%Y%m%d')
df5['document_create_date.1']=pd.to_datetime(df5['document_create_date.1'], format='%Y%m%d')

# %%
df5['due_in_date']=df5['due_in_date'].astype(str)
df5['due_in_date']=df5['due_in_date'].str[:-2]

# %%
df5['due_in_date']=pd.to_datetime(df5['due_in_date'], format='%Y%m%d')

# %%
df5
# Out:
#       Unnamed: 0  Unnamed: 0.1  business_code_x  cust_number_x  \
# 0              0             4                2              1
# 1              1            13                2             10
# 2              2            22                2              5
# 3              3            29                2              1
# 4              4            45                2              1
# ...          ...           ...              ...            ...
# 9987        9987         49982                2              5
# 9988        9988         49985                2              1
# 9989        9989         49987                2              1
# 9990        9990         49988                2              1
# 9991        9991         49994                2              4
#
#       total_open_amount_x  cust_payment_terms_x  document_create_date_day  \
# 0                95651.82               15506.0                        11
# 1                12446.28                 462.0                         7
# 2                11889.49               15506.0                         6
# 3                20691.83               10524.0                        21
# 4                 8058.89                 590.0                        31
# ...                   ...                   ...                       ...
# 9987               132.72               15506.0                        27
# 9988             53216.50               10524.0                        22
# 9989              1322.22               10524.0                        18
# 9990             73209.62               15506.0                         3
# 9991             18815.63               15506.0                        13
#
#       document_create_date_month  document_create_date_year  \
# 0                              4                       2020
# 1                              3                       2020
# 2                              4                       2020
# 3                              3                       2020
# 4                              3                       2020
# ...                          ...                        ...
# 9987                           4                       2020
# 9988                           3                       2020
# 9989                           3                       2020
# 9990                           3                       2020
# 9991                           4                       2020
#
#       document_create_date_quarter  delay Payment date prediction  \
# 0                                2     -1              2020-04-27
# 1                                1      2              2020-03-13
# 2                                2      1              2020-04-22
# 3                                1      0              2020-04-06
# 4                                1    -29              2020-05-07
# ...                            ...    ...                     ...
# 9987                             2      4              2020-05-15
# 9988                             1      0              2020-04-07
# 9989                             1      0              2020-04-03
# 9990                             1     -2              2020-03-16
# 9991                             2      1              2020-04-30
#
#      Aging_Bucket business_code_y cust_number_y    name_customer  clear_date  \
# 0          0 days            U001    0100031704      DELHAIZE in         NaN
# 1        1-15days            U001    0200803720      DEC systems         NaN
# 2        1-15days            U001    0200701314          MBM  co         NaN
# 3          0 days            U001    0200769623       WAL-MAR us         NaN
# 4          0 days            U001    0200769623    WAL-MAR trust         NaN
# ...           ...             ...           ...              ...         ...
# 9987     1-15days            U001    0200726979    BJ'S  systems         NaN
# 9988       0 days            U001     200769623  WAL-MAR systems         NaN
# 9989       0 days            U001    0200769623     WAL-MAR corp         NaN
# 9990       0 days            U001    0200792734          MDV/ co         NaN
# 9991     1-15days            U001    0100036039            GI us         NaN
#
#       buisness_year        doc_id posting_date document_create_date  \
# 0            2020.0  1.930778e+09   2020-04-13           2020-04-11
# 1            2020.0  1.930618e+09   2020-03-07           2020-03-07
# 2            2020.0  1.930751e+09   2020-04-06           2020-04-06
# 3            2020.0  1.930684e+09   2020-03-22           2020-03-21
# 4            2020.0  1.930726e+09   2020-04-01           2020-03-31
# ...             ...           ...          ...                  ...
# 9987         2020.0  1.930828e+09   2020-04-26           2020-04-27
# 9988         2020.0  1.930686e+09   2020-03-23           2020-03-22
# 9989         2020.0  1.930666e+09   2020-03-19           2020-03-18
# 9990         2020.0  1.930593e+09   2020-03-03           2020-03-03
# 9991         2020.0  1.930781e+09   2020-04-14           2020-04-13
#
#      document_create_date.1 due_in_date invoice_currency document type  \
# 0                2020-04-13  2020-04-28              USD            RV
# 1                2020-03-07  2020-03-11              USD            RV
# 2                2020-04-06  2020-04-21              USD            RV
# 3                2020-03-22  2020-04-06              USD            RV
# 4                2020-04-01  2020-06-05              USD            RV
# ...                     ...         ...              ...           ...
# 9987             2020-04-26  2020-05-11              USD            RV
# 9988             2020-03-23  2020-04-07              USD            RV
# 9989             2020-03-19  2020-04-03              USD            RV
# 9990             2020-03-03  2020-03-18              USD            RV
# 9991             2020-04-14  2020-04-29              USD            RV
#
#       posting_id  area_business  total_open_amount_y  baseline_create_date  \
# 0            1.0            NaN             95651.82            20200413.0
# 1            1.0            NaN             12446.28            20200301.0
# 2            1.0            NaN             11889.49            20200406.0
# 3            1.0            NaN             20691.83            20200322.0
# 4            1.0            NaN              8058.89            20200401.0
# ...          ...            ...                  ...                   ...
# 9987         1.0            NaN               132.72            20200426.0
# 9988         1.0            NaN             53216.50            20200323.0
# 9989         1.0            NaN              1322.22            20200319.0
# 9990         1.0            NaN             73209.62            20200303.0
# 9991         1.0            NaN             18815.63            20200414.0
#
#      cust_payment_terms_y    invoice_id  isOpen
# 0                    NAA8  1.930778e+09       1
# 1                    NAM2  1.930618e+09       1
# 2                    NAA8  1.930751e+09       1
# 3                    NAH4  1.930684e+09       1
# 4                    NAGD  1.930726e+09       1
# ...                   ...           ...     ...
# 9987                 NAA8  1.930828e+09       1
# 9988                 NAH4  1.930686e+09       1
# 9989                 NAH4  1.930666e+09       1
# 9990                 NAA8  1.930593e+09       1
# 9991                 NAA8  1.930781e+09       1
#
# [9992 rows x 32 columns]

# %%
df5['invoice_id']=df5['invoice_id'].astype(str)
df5['doc_id']=df5['doc_id'].astype(str)

# %%
df5['baseline_create_date']=df5['baseline_create_date'].astype(str)
df5['baseline_create_date']=df5['baseline_create_date'].str[:-2]
df5['baseline_create_date']=pd.to_datetime(df5['baseline_create_date'], format='%Y%m%d')

# %%
df5
# Out:
#       Unnamed: 0  Unnamed: 0.1  business_code_x  cust_number_x  \
# 0              0             4                2              1
# 1              1            13                2             10
# 2              2            22                2              5
# 3              3            29                2              1
# 4              4            45                2              1
# ...          ...           ...              ...            ...
# 9987        9987         49982                2              5
# 9988        9988         49985                2              1
# 9989        9989         49987                2              1
# 9990        9990         49988                2              1
# 9991        9991         49994                2              4
#
#       total_open_amount_x  cust_payment_terms_x  document_create_date_day  \
# 0                95651.82               15506.0                        11
# 1                12446.28                 462.0                         7
# 2                11889.49               15506.0                         6
# 3                20691.83               10524.0                        21
# 4                 8058.89                 590.0                        31
# ...                   ...                   ...                       ...
# 9987               132.72               15506.0                        27
# 9988             53216.50               10524.0                        22
# 9989              1322.22               10524.0                        18
# 9990             73209.62               15506.0                         3
# 9991             18815.63               15506.0                        13
#
#       document_create_date_month  document_create_date_year  \
# 0                              4                       2020
# 1                              3                       2020
# 2                              4                       2020
# 3                              3                       2020
# 4                              3                       2020
# ...                          ...                        ...
# 9987                           4                       2020
# 9988                           3                       2020
# 9989                           3                       2020
# 9990                           3                       2020
# 9991                           4                       2020
#
#       document_create_date_quarter  delay Payment date prediction  \
# 0                                2     -1              2020-04-27
# 1                                1      2              2020-03-13
# 2                                2      1              2020-04-22
# 3                                1      0              2020-04-06
# 4                                1    -29              2020-05-07
# ...                            ...    ...                     ...
# 9987                             2      4              2020-05-15
# 9988                             1      0              2020-04-07
# 9989                             1      0              2020-04-03
# 9990                             1     -2              2020-03-16
# 9991                             2      1              2020-04-30
#
#      Aging_Bucket business_code_y cust_number_y    name_customer  clear_date  \
# 0          0 days            U001    0100031704      DELHAIZE in         NaN
# 1        1-15days            U001    0200803720      DEC systems         NaN
# 2        1-15days            U001    0200701314          MBM  co         NaN
# 3          0 days            U001    0200769623       WAL-MAR us         NaN
# 4          0 days            U001    0200769623    WAL-MAR trust         NaN
# ...           ...             ...           ...              ...         ...
# 9987     1-15days            U001    0200726979    BJ'S  systems         NaN
# 9988       0 days            U001     200769623  WAL-MAR systems         NaN
# 9989       0 days            U001    0200769623     WAL-MAR corp         NaN
# 9990       0 days            U001    0200792734          MDV/ co         NaN
# 9991     1-15days            U001    0100036039            GI us         NaN
#
#       buisness_year        doc_id posting_date document_create_date  \
# 0            2020.0  1930778026.0   2020-04-13           2020-04-11
# 1            2020.0  1930617757.0   2020-03-07           2020-03-07
# 2            2020.0  1930750661.0   2020-04-06           2020-04-06
# 3            2020.0  1930683636.0   2020-03-22           2020-03-21
# 4            2020.0  1930726056.0   2020-04-01           2020-03-31
# ...             ...           ...          ...                  ...
# 9987         2020.0  1930827991.0   2020-04-26           2020-04-27
# 9988         2020.0  1930685722.0   2020-03-23           2020-03-22
# 9989         2020.0  1930666217.0   2020-03-19           2020-03-18
# 9990         2020.0  1930592799.0   2020-03-03           2020-03-03
# 9991         2020.0  1930781251.0   2020-04-14           2020-04-13
#
#      document_create_date.1 due_in_date invoice_currency document type  \
# 0                2020-04-13  2020-04-28              USD            RV
# 1                2020-03-07  2020-03-11              USD            RV
# 2                2020-04-06  2020-04-21              USD            RV
# 3                2020-03-22  2020-04-06              USD            RV
# 4                2020-04-01  2020-06-05              USD            RV
# ...                     ...         ...              ...           ...
# 9987             2020-04-26  2020-05-11              USD            RV
# 9988             2020-03-23  2020-04-07              USD            RV
# 9989             2020-03-19  2020-04-03              USD            RV
# 9990             2020-03-03  2020-03-18              USD            RV
# 9991             2020-04-14  2020-04-29              USD            RV
#
#       posting_id  area_business  total_open_amount_y baseline_create_date  \
# 0            1.0            NaN             95651.82           2020-04-13
# 1            1.0            NaN             12446.28           2020-03-01
# 2            1.0            NaN             11889.49           2020-04-06
# 3            1.0            NaN             20691.83           2020-03-22
# 4            1.0            NaN              8058.89           2020-04-01
# ...          ...            ...                  ...                  ...
# 9987         1.0            NaN               132.72           2020-04-26
# 9988         1.0            NaN             53216.50           2020-03-23
# 9989         1.0            NaN              1322.22           2020-03-19
# 9990         1.0            NaN             73209.62           2020-03-03
# 9991         1.0            NaN             18815.63           2020-04-14
#
#      cust_payment_terms_y    invoice_id  isOpen
# 0                    NAA8  1930778026.0       1
# 1                    NAM2  1930617757.0       1
# 2                    NAA8  1930750661.0       1
# 3                    NAH4  1930683636.0       1
# 4                    NAGD  1930726056.0       1
# ...                   ...           ...     ...
# 9987                 NAA8  1930827991.0       1
# 9988                 NAH4  1930685722.0       1
# 9989                 NAH4  1930666217.0       1
# 9990                 NAA8  1930592799.0       1
# 9991                 NAA8  1930781251.0       1
#
# [9992 rows x 32 columns]

# %%
df6=df5.to_csv("Train4.csv")

# %%
data4=pd.read_csv('Train4.csv')
df6=pd.DataFrame(data4)
df6
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  business_code_x  \
# 0              0             0               4                2
# 1              1             1              13                2
# 2              2             2              22                2
# 3              3             3              29                2
# 4              4             4              45                2
# ...          ...           ...             ...              ...
# 9987        9987          9987           49982                2
# 9988        9988          9988           49985                2
# 9989        9989          9989           49987                2
# 9990        9990          9990           49988                2
# 9991        9991          9991           49994                2
#
#       cust_number_x  total_open_amount_x  cust_payment_terms_x  \
# 0                 1             95651.82               15506.0
# 1                10             12446.28                 462.0
# 2                 5             11889.49               15506.0
# 3                 1             20691.83               10524.0
# 4                 1              8058.89                 590.0
# ...             ...                  ...                   ...
# 9987              5               132.72               15506.0
# 9988              1             53216.50               10524.0
# 9989              1              1322.22               10524.0
# 9990              1             73209.62               15506.0
# 9991              4             18815.63               15506.0
#
#       document_create_date_day  document_create_date_month  \
# 0                           11                           4
# 1                            7                           3
# 2                            6                           4
# 3                           21                           3
# 4                           31                           3
# ...                        ...                         ...
# 9987                        27                           4
# 9988                        22                           3
# 9989                        18                           3
# 9990                         3                           3
# 9991                        13                           4
#
#       document_create_date_year  document_create_date_quarter  delay  \
# 0                          2020                             2     -1
# 1                          2020                             1      2
# 2                          2020                             2      1
# 3                          2020                             1      0
# 4                          2020                             1    -29
# ...                         ...                           ...    ...
# 9987                       2020                             2      4
# 9988                       2020                             1      0
# 9989                       2020                             1      0
# 9990                       2020                             1     -2
# 9991                       2020                             2      1
#
#      Payment date prediction Aging_Bucket business_code_y cust_number_y  \
# 0                 2020-04-27       0 days            U001    0100031704
# 1                 2020-03-13     1-15days            U001    0200803720
# 2                 2020-04-22     1-15days            U001    0200701314
# 3                 2020-04-06       0 days            U001    0200769623
# 4                 2020-05-07       0 days            U001    0200769623
# ...                      ...          ...             ...           ...
# 9987              2020-05-15     1-15days            U001    0200726979
# 9988              2020-04-07       0 days            U001     200769623
# 9989              2020-04-03       0 days            U001    0200769623
# 9990              2020-03-16       0 days            U001    0200792734
# 9991              2020-04-30     1-15days            U001    0100036039
#
#         name_customer  clear_date  buisness_year        doc_id posting_date  \
# 0         DELHAIZE in         NaN         2020.0  1.930778e+09   2020-04-13
# 1         DEC systems         NaN         2020.0  1.930618e+09   2020-03-07
# 2             MBM  co         NaN         2020.0  1.930751e+09   2020-04-06
# 3          WAL-MAR us         NaN         2020.0  1.930684e+09   2020-03-22
# 4       WAL-MAR trust         NaN         2020.0  1.930726e+09   2020-04-01
# ...               ...         ...            ...           ...          ...
# 9987    BJ'S  systems         NaN         2020.0  1.930828e+09   2020-04-26
# 9988  WAL-MAR systems         NaN         2020.0  1.930686e+09   2020-03-23
# 9989     WAL-MAR corp         NaN         2020.0  1.930666e+09   2020-03-19
# 9990          MDV/ co         NaN         2020.0  1.930593e+09   2020-03-03
# 9991            GI us         NaN         2020.0  1.930781e+09   2020-04-14
#
#      document_create_date document_create_date.1 due_in_date invoice_currency  \
# 0              2020-04-11             2020-04-13  2020-04-28              USD
# 1              2020-03-07             2020-03-07  2020-03-11              USD
# 2              2020-04-06             2020-04-06  2020-04-21              USD
# 3              2020-03-21             2020-03-22  2020-04-06              USD
# 4              2020-03-31             2020-04-01  2020-06-05              USD
# ...                   ...                    ...         ...              ...
# 9987           2020-04-27             2020-04-26  2020-05-11              USD
# 9988           2020-03-22             2020-03-23  2020-04-07              USD
# 9989           2020-03-18             2020-03-19  2020-04-03              USD
# 9990           2020-03-03             2020-03-03  2020-03-18              USD
# 9991           2020-04-13             2020-04-14  2020-04-29              USD
#
#      document type  posting_id  area_business  total_open_amount_y  \
# 0               RV         1.0            NaN             95651.82
# 1               RV         1.0            NaN             12446.28
# 2               RV         1.0            NaN             11889.49
# 3               RV         1.0            NaN             20691.83
# 4               RV         1.0            NaN              8058.89
# ...            ...         ...            ...                  ...
# 9987            RV         1.0            NaN               132.72
# 9988            RV         1.0            NaN             53216.50
# 9989            RV         1.0            NaN              1322.22
# 9990            RV         1.0            NaN             73209.62
# 9991            RV         1.0            NaN             18815.63
#
#      baseline_create_date cust_payment_terms_y    invoice_id  isOpen
# 0              2020-04-13                 NAA8  1.930778e+09       1
# 1              2020-03-01                 NAM2  1.930618e+09       1
# 2              2020-04-06                 NAA8  1.930751e+09       1
# 3              2020-03-22                 NAH4  1.930684e+09       1
# 4              2020-04-01                 NAGD  1.930726e+09       1
# ...                   ...                  ...           ...     ...
# 9987           2020-04-26                 NAA8  1.930828e+09       1
# 9988           2020-03-23                 NAH4  1.930686e+09       1
# 9989           2020-03-19                 NAH4  1.930666e+09       1
# 9990           2020-03-03                 NAA8  1.930593e+09       1
# 9991           2020-04-14                 NAA8  1.930781e+09       1
#
# [9992 rows x 33 columns]

# %%
df6=df6.drop(columns=['Unnamed: 0','Unnamed: 0.1'],axis=1)

# %%
df6
# Out:
#       Unnamed: 0.1.1  business_code_x  cust_number_x  total_open_amount_x  \
# 0                  4                2              1             95651.82
# 1                 13                2             10             12446.28
# 2                 22                2              5             11889.49
# 3                 29                2              1             20691.83
# 4                 45                2              1              8058.89
# ...              ...              ...            ...                  ...
# 9987           49982                2              5               132.72
# 9988           49985                2              1             53216.50
# 9989           49987                2              1              1322.22
# 9990           49988                2              1             73209.62
# 9991           49994                2              4             18815.63
#
#       cust_payment_terms_x  document_create_date_day  \
# 0                  15506.0                        11
# 1                    462.0                         7
# 2                  15506.0                         6
# 3                  10524.0                        21
# 4                    590.0                        31
# ...                    ...                       ...
# 9987               15506.0                        27
# 9988               10524.0                        22
# 9989               10524.0                        18
# 9990               15506.0                         3
# 9991               15506.0                        13
#
#       document_create_date_month  document_create_date_year  \
# 0                              4                       2020
# 1                              3                       2020
# 2                              4                       2020
# 3                              3                       2020
# 4                              3                       2020
# ...                          ...                        ...
# 9987                           4                       2020
# 9988                           3                       2020
# 9989                           3                       2020
# 9990                           3                       2020
# 9991                           4                       2020
#
#       document_create_date_quarter  delay Payment date prediction  \
# 0                                2     -1              2020-04-27
# 1                                1      2              2020-03-13
# 2                                2      1              2020-04-22
# 3                                1      0              2020-04-06
# 4                                1    -29              2020-05-07
# ...                            ...    ...                     ...
# 9987                             2      4              2020-05-15
# 9988                             1      0              2020-04-07
# 9989                             1      0              2020-04-03
# 9990                             1     -2              2020-03-16
# 9991                             2      1              2020-04-30
#
#      Aging_Bucket business_code_y cust_number_y    name_customer  clear_date  \
# 0          0 days            U001    0100031704      DELHAIZE in         NaN
# 1        1-15days            U001    0200803720      DEC systems         NaN
# 2        1-15days            U001    0200701314          MBM  co         NaN
# 3          0 days            U001    0200769623       WAL-MAR us         NaN
# 4          0 days            U001    0200769623    WAL-MAR trust         NaN
# ...           ...             ...           ...              ...         ...
# 9987     1-15days            U001    0200726979    BJ'S  systems         NaN
# 9988       0 days            U001     200769623  WAL-MAR systems         NaN
# 9989       0 days            U001    0200769623     WAL-MAR corp         NaN
# 9990       0 days            U001    0200792734          MDV/ co         NaN
# 9991     1-15days            U001    0100036039            GI us         NaN
#
#       buisness_year        doc_id posting_date document_create_date  \
# 0            2020.0  1.930778e+09   2020-04-13           2020-04-11
# 1            2020.0  1.930618e+09   2020-03-07           2020-03-07
# 2            2020.0  1.930751e+09   2020-04-06           2020-04-06
# 3            2020.0  1.930684e+09   2020-03-22           2020-03-21
# 4            2020.0  1.930726e+09   2020-04-01           2020-03-31
# ...             ...           ...          ...                  ...
# 9987         2020.0  1.930828e+09   2020-04-26           2020-04-27
# 9988         2020.0  1.930686e+09   2020-03-23           2020-03-22
# 9989         2020.0  1.930666e+09   2020-03-19           2020-03-18
# 9990         2020.0  1.930593e+09   2020-03-03           2020-03-03
# 9991         2020.0  1.930781e+09   2020-04-14           2020-04-13
#
#      document_create_date.1 due_in_date invoice_currency document type  \
# 0                2020-04-13  2020-04-28              USD            RV
# 1                2020-03-07  2020-03-11              USD            RV
# 2                2020-04-06  2020-04-21              USD            RV
# 3                2020-03-22  2020-04-06              USD            RV
# 4                2020-04-01  2020-06-05              USD            RV
# ...                     ...         ...              ...           ...
# 9987             2020-04-26  2020-05-11              USD            RV
# 9988             2020-03-23  2020-04-07              USD            RV
# 9989             2020-03-19  2020-04-03              USD            RV
# 9990             2020-03-03  2020-03-18              USD            RV
# 9991             2020-04-14  2020-04-29              USD            RV
#
#       posting_id  area_business  total_open_amount_y baseline_create_date  \
# 0            1.0            NaN             95651.82           2020-04-13
# 1            1.0            NaN             12446.28           2020-03-01
# 2            1.0            NaN             11889.49           2020-04-06
# 3            1.0            NaN             20691.83           2020-03-22
# 4            1.0            NaN              8058.89           2020-04-01
# ...          ...            ...                  ...                  ...
# 9987         1.0            NaN               132.72           2020-04-26
# 9988         1.0            NaN             53216.50           2020-03-23
# 9989         1.0            NaN              1322.22           2020-03-19
# 9990         1.0            NaN             73209.62           2020-03-03
# 9991         1.0            NaN             18815.63           2020-04-14
#
#      cust_payment_terms_y    invoice_id  isOpen
# 0                    NAA8  1.930778e+09       1
# 1                    NAM2  1.930618e+09       1
# 2                    NAA8  1.930751e+09       1
# 3                    NAH4  1.930684e+09       1
# 4                    NAGD  1.930726e+09       1
# ...                   ...           ...     ...
# 9987                 NAA8  1.930828e+09       1
# 9988                 NAH4  1.930686e+09       1
# 9989                 NAH4  1.930666e+09       1
# 9990                 NAA8  1.930593e+09       1
# 9991                 NAA8  1.930781e+09       1
#
# [9992 rows x 31 columns]

# %%
df6 = df6.rename(columns={"Unnamed: 0.1.1":"Unnamed: 0"})

# %%
df7=df6.to_csv("Train5.csv")

# %% [markdown]
# # All Completed
